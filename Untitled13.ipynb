# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Q1: Create two charts using list and dataframe

# %%
df = pd.read_csv('/Users/hamadbinmohammed/labs/tmdb-movies.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
#  15  release_date          10866 non-null  object
#  16  vote_count            10866 non-null  int64
#  17  vote_average          10866 non-null  float64
#  18  release_year          10866 non-null  int64
#  19  budget_adj            10866 non-null  float64
#  20  revenue_adj           10866 non-null  float64
# dtypes: float64(4), int64(6), object(11)
# memory usage: 1.7+ MB

# %% [markdown]
# # Q2: Create pie chart with equal explode values.

# %%
genres = ['Comedy','Drama','Comedy|Romance','Adventure|Action|Thriller','Comedy|Drama|Romance']
sizes = [ 20323889661,15107533347,11545724341,7597483556,7251175696]

colors = ['r','g','b','y','c']

plt.pie(sizes,labels=genres, autopct='%1.2f%%', colors =colors,  startangle=180, radius=1.5)

plt.show()

# %%
genres = ['Comedy','Drama','Comedy|Romance','Adventure|Action|Thriller','Comedy|Drama|Romance']
sizes = [ 20323889661,15107533347,11545724341,7597483556,7251175696]

plt.pie(sizes,labels=genres, autopct='%1.1f%%', startangle=90, shadow=True, radius=1, explode = [0.3,0.2,0,0,0])

plt.show()

# %% [markdown]
# # Q3: Create a scatter chart with circle marker, alpha = 0.4, and size = 50.

# %%
plt.scatter(df['vote_average'],df['revenue'], alpha = 0.4,s = 50 ) # alpha between 0 (transparent) and 1 (opaque)

plt.title('Profit vs. Vote Average',fontsize = 10)
plt.xlabel('Vote Average',fontsize = 10)
plt.ylabel('Profit',fontsize = 10)


plt.show()

# %% [markdown]
# # Q4: Add the following to your chart:
# - title placed in the left and has a red color
# - x and y label with font size = 16

# %%
plt.scatter(x, y, s=50, alpha=0.4, marker='o')

plt.title('movies', loc='left', color='red', fontsize=16)

plt.xlabel('X', fontsize=16)
plt.ylabel('Y', fontsize=16)
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# # Q5: Create three line charts with Legends at left and colors.

# %%
plt.plot([1,2,0,4,5], 'g')
plt.plot([10,9,8,6,3], c ='lime')
plt.plot([12,13, 10, 20,13], color ='blue')
plt.legend(['Cartoon','Movies','Series'], shadow = True, loc = (0, 1))

# %% [markdown]
# # Q6: Create subplots with three charts and figsize=20,10.

# %%
plt.figure(figsize=[20,10])
plt.suptitle('Subplots',fontsize = 20)

plt.subplot(3,1,1) #(number of rows, number of columns, number of plot)
plt.pie(sizes,labels=genres, autopct='%1.1f%%')
plt.title('Genres');


plt.subplot(3,1,2)
plt.scatter(df['vote_average'],df['revenue'])
plt.title('Profit vs. Vote Average')
plt.xlabel('Vote Average')
plt.ylabel('Profit');

plt.subplot(3,1,3)
plt.scatter(df['vote_average'],df['revenue'])
plt.title('Profit vs. Vote Average')
plt.xlabel('Vote Average')
plt.ylabel('Profit');
