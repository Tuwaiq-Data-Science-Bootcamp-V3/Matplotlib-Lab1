# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Q1: Create two charts using list and dataframe.

# %%
ads=[2,6,5,7.5]
sales=pd.DataFrame([4,10,3,11],index=["April","May","June","July"])
plt.plot(x)
plt.plot(sales, c ='green', linestyle = 'solid', linewidth = 3)

#+++
plt.ylabel('million Riyals',fontsize = 20)
plt.xlabel('month',fontsize = 20)
plt.xlabel('month',fontsize = 20)
plt.title('sales Vs Ads')
plt.legend([' ads','sales',], loc = 0)

# %% [markdown]
# ## Q2: Create pie chart with equal explode values.

# %%
product=['phone','laptop','TV','ipad']
avg_sales=[50, 100, 55, 90]
plt.pie(y,labels=product,autopct='%1.2f%%', startangle=90, shadow=True, radius=1, explode = [0.2,0.2,0.2,0.2]);

# %% [markdown]
# ## Q3: Create a scatter chart with circle marker, alpha = 0.4, and size = 50.

# %%
plt.plot(product,avg_sales , marker = 'o', markersize = 50,alpha = 0.4,markerfacecolor = 'blue', markeredgewidth= 3, markeredgecolor= 'green');

# %% [markdown]
# ## Q4: Add the following to your chart:
# - title placed in the left and has a red color
# - x and y label with font size = 16

# %%
plt.plot(product, avg_sales, marker = 'o', markersize = 50,alpha = 0.4,markerfacecolor = 'blue', markeredgewidth= 3, markeredgecolor= 'green');
plt.ylabel('number of product',fontsize = 16)
plt.xlabel('product type',fontsize = 16)
plt.title('sales June 2022',loc='left', color= 'red')
# Out:
# Text(0.0, 1.0, 'sales June 2022')

# %% [markdown]
# ## Q5: Create three line charts with Legends at left and colors.

# %%
plt.plot([4,5,3,2], color='#99ff99')
plt.plot([10,102,22,100], color ='#66b3ff')
plt.plot([40,35,300,100], color ='#ff9999')
plt.legend(['june-sales ',' may-sales','october-sales '], loc = 0)

# %% [markdown]
# ## Q6: Create subplots with three charts and figsize=20,10.

# %%
plt.figure(figsize=[20,10])

#first
plt.subplot(1,3,1) 
plt.plot(product, avg_sales, marker = 'o', markersize = 50,alpha = 0.4,markerfacecolor = 'blue', markeredgewidth= 3, markeredgecolor= 'green');
plt.ylabel('number of product',fontsize = 16)
plt.xlabel('product type',fontsize = 16)
plt.title('sales June 2022',loc='left', color= 'red')

#second
plt.subplot(1,3,2) 
product=['phone','labtop','tablet','ipad']
avg_sales=[50, 100, 55, 90]
plt.pie(y,labels=product,autopct='%1.2f%%', startangle=90, shadow=True, radius=1, explode = [0.2,0.2,0.2,0.2]);
#second
plt.subplot(1,3,3)
plt.plot([4,5,3,2], color='#99ff99')
plt.plot([10,102,22,100], color ='#66b3ff')
plt.plot([40,35,300,100], color ='#ff9999')
plt.legend(['june-sales ',' may-sales','october-sales '], loc = 0)
